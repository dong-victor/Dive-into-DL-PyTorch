# %%
import torch
import torch.nn as nn
import torchvision
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms

writer = SummaryWriter('../logs')

# %%
trian_data = torchvision.datasets.CIFAR10('../dataset', train=True, transform=transforms.ToTensor())
dataloader = DataLoader(dataset=trian_data, batch_size=64, shuffle=False, num_workers=0, drop_last=True)

# %%
class TestMaxPool(nn.Module):
    def __init__(self):
        super(TestMaxPool, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 3)
        self.relu = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=3, ceil_mode=True)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        return self.pool1(x)

# %%
test = TestMaxPool()
step = 0

for data in dataloader:
    imgs, _ = data
    writer.add_images('MaxPool_Input', imgs, step)
    output = test(imgs)
    output = torch.reshape(output, (-1, 3, 10, 10))
    writer.add_images('MaxPool_Output', output, step)
    step += 1

# %%
writer.close()
