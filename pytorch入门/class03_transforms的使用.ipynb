# %%
from torchvision import transforms
from PIL import Image
from torch.utils.tensorboard import SummaryWriter

# %%
image = Image.open("../dataset/0Q3A0032.JPG")
tensor_trans = transforms.ToTensor()
tensor_image = tensor_trans(image)
print(tensor_image)
# Out:
# tensor([[[0.8510, 0.8510, 0.8549,  ..., 0.7765, 0.7804, 0.7804],
#          [0.8510, 0.8510, 0.8588,  ..., 0.7804, 0.7765, 0.7725],
#          [0.8510, 0.8549, 0.8588,  ..., 0.7804, 0.7725, 0.7686],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.7882, 0.7882, 0.7922],
#          [0.0078, 0.0000, 0.0039,  ..., 0.7882, 0.7882, 0.7882],
#          [0.0000, 0.0000, 0.0000,  ..., 0.7882, 0.7882, 0.7922]],
#
#         [[0.8941, 0.8941, 0.8980,  ..., 0.8353, 0.8392, 0.8392],
#          [0.8941, 0.8941, 0.9020,  ..., 0.8392, 0.8353, 0.8314],
#          [0.8941, 0.8980, 0.9020,  ..., 0.8392, 0.8314, 0.8275],
#          ...,
#          [0.4157, 0.4196, 0.3843,  ..., 0.8471, 0.8471, 0.8510],
#          [0.4392, 0.4314, 0.4235,  ..., 0.8471, 0.8471, 0.8471],
#          [0.4549, 0.4431, 0.4314,  ..., 0.8471, 0.8471, 0.8510]],
#
#         [[0.9020, 0.9020, 0.9059,  ..., 0.8471, 0.8510, 0.8510],
#          [0.9020, 0.9020, 0.9098,  ..., 0.8510, 0.8471, 0.8431],
#          [0.9020, 0.9059, 0.9098,  ..., 0.8510, 0.8431, 0.8392],
#          ...,
#          [0.7216, 0.7412, 0.7098,  ..., 0.8588, 0.8588, 0.8627],
#          [0.7490, 0.7529, 0.7373,  ..., 0.8588, 0.8588, 0.8588],
#          [0.7412, 0.7412, 0.7255,  ..., 0.8588, 0.8588, 0.8627]]])

# %%
writer = SummaryWriter('../logs')

# %%
writer.add_image('test_transforms', tensor_image, 0)

# %%
writer.close()
