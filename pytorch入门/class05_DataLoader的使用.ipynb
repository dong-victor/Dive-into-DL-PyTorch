# %% [markdown]
# ## Dataset DataLoader

# %%
import torchvision
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms

writer = SummaryWriter('../logs')

# %%
data_train = torchvision.datasets.CIFAR10('../dataset', train=True, transform=transforms.ToTensor())
data_list = DataLoader(dataset=data_train, batch_size=64, shuffle=True, num_workers=0, drop_last=False)

# %%
i = 0
for data in data_list:
    images, targets = data
    writer.add_images('DataLoader', images, i)
    i += 1

# %%
writer.close()
